# %% [markdown]
# # Air Lines Customer Satisfaction

# %% [markdown]
# We are importing required libraries and dataset file

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv ('Invistico_Airline.csv')
df1=df.copy()
df.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %% [markdown]
#  we are changing some of the qualitative values to integer values for better analysis

# %%
df.replace("satisfied",int(1),inplace=True)
df.replace("dissatisfied",int(0),inplace=True)
df.replace("Eco",int(0),inplace=True)
df.replace("Business",int(2),inplace=True)
df.replace("Eco Plus",int(1),inplace=True)
df.replace("Loyal Customer",int(1),inplace=True)
df.replace("disloyal Customer",int(0),inplace=True)
df.head()
# Out:
#    satisfaction  Gender  Customer Type  Age   Type of Travel  Class  \
# 0             1  Female              1   65  Personal Travel      0
# 1             1    Male              1   47  Personal Travel      2
# 2             1  Female              1   15  Personal Travel      0
# 3             1  Female              1   60  Personal Travel      0
# 4             1  Female              1   70  Personal Travel      0
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# 0               0  ...               2                       3
# ...

# %% [markdown]
# Some description about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  int64
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  int64
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#         satisfaction  Customer Type            Age          Class  \
# count  129880.000000  129880.000000  129880.000000  129880.000000
# mean        0.547328       0.816908      39.427957       1.029650
# std         0.497757       0.386743      15.119360       0.962636
# min         0.000000       0.000000       7.000000       0.000000
# 25%         0.000000       1.000000      27.000000       0.000000
# 50%         1.000000       1.000000      40.000000       1.000000
# 75%         1.000000       1.000000      51.000000       2.000000
# max         1.000000       1.000000      85.000000       2.000000
#
#        Flight Distance   Seat comfort  Departure/Arrival time convenient  \
# count    129880.000000  129880.000000                      129880.000000
# mean       1981.409055       2.838597                           2.990645
# std        1027.115606       1.392983                           1.527224
# min          50.000000       0.000000                           0.000000
# ...

# %%
df.columns
# Out:
# Index(['satisfaction', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
attributes = ['Seat comfort',
       'Departure/Arrival time convenient', 'Food and drink',
       'Inflight wifi service', 'Inflight entertainment', 'Online support',
       'Ease of Online booking', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding']
for x in attributes:
    print(f'''Value count column {x}:''')
    print(df[x].value_counts())
    print()
# Out:
# Value count column Seat comfort:
# 3    29183
# 2    28726
# 4    28398
# 1    20949
# 5    17827
# 0     4797
# Name: Seat comfort, dtype: int64
#
# Value count column Departure/Arrival time convenient:
# 4    29593
# 5    26817
# 3    23184
# 2    22794
# 1    20828
# 0     6664
# Name: Departure/Arrival time convenient, dtype: int64
#
# Value count column Food and drink:
# 3    28150
# 4    27216
# 2    27146
# 1    21076
# 5    20347
# 0     5945
# Name: Food and drink, dtype: int64
#
# Value count column Inflight wifi service:
# 4    31560
# 5    28830
# 3    27602
# 2    27045
# 1    14711
# 0      132
# Name: Inflight wifi service, dtype: int64
#
# Value count column Inflight entertainment:
# 4    41879
# 5    29831
# 3    24200
# 2    19183
# 1    11809
# 0     2978
# Name: Inflight entertainment, dtype: int64
#
# Value count column Online support:
# 4    41510
# 5    35563
# 3    21609
# 2    17260
# 1    13937
# 0        1
# Name: Online support, dtype: int64
#
# ...

# %%
heatmp = df.corr()
  
f, ax = plt.subplots(figsize =(12, 10))
sns.heatmap(heatmp, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %% [markdown]
# We are removing some of the columns which are not required for analysis
# The columns Gate location and Type of travel are not required for the data set which are not giving any insights

# %%
df.drop('Gate location',axis=1,inplace=True)

# %%
df.drop('Type of Travel',axis=1,inplace=True)

# %%
df.head()
# Out:
#    satisfaction  Gender  Customer Type  Age  Class  Flight Distance  \
# 0             1  Female              1   65      0              265
# 1             1    Male              1   47      2             2464
# 2             1  Female              1   15      0             2138
# 3             1  Female              1   60      0              623
# 4             1  Female              1   70      0              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Inflight wifi service  ...  Online support  Ease of Online booking  \
# 0                      2  ...               2                       3
# ...

# %%
df.columns
# Out:
# Index(['satisfaction', 'Gender', 'Customer Type', 'Age', 'Class',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Inflight wifi service', 'Inflight entertainment',
#        'Online support', 'Ease of Online booking', 'On-board service',
#        'Leg room service', 'Baggage handling', 'Checkin service',
#        'Cleanliness', 'Online boarding', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
sns.barplot(x = 'Class',y = 'satisfaction',data = df)

# %%
sns.barplot(x = 'satisfaction',y = 'Food and drink',data = df)

# %%
sns.barplot(x = 'satisfaction',y = 'Flight Distance',data = df)

# %%
sns.barplot(x = 'satisfaction',y = 'Seat comfort',data = df)

# %%
df['Totaldelay']=df['Departure Delay in Minutes']+df['Arrival Delay in Minutes']
sns.barplot(x = 'satisfaction',y = 'Totaldelay',data = df)

# %%
df['onlineservices']=(df['Online support']+df['Ease of Online booking']+df['Online boarding'])/3
sns.barplot(x = 'satisfaction',y = 'onlineservices',data = df)

# %%
df_satisfied=df1[df1['satisfaction']=='satisfied']
df_dissatisfied=df1[df1['satisfaction']=='dissatisfied']
col=['Seat comfort','Food and drink','Inflight entertainment','On-board service','Cleanliness']
data_s=[df_satisfied['Seat comfort'].mean(),df_satisfied['Food and drink'].mean(),df_satisfied['Inflight entertainment'].mean(),df_satisfied['On-board service'].mean(),df_satisfied['Cleanliness'].mean()]
fig_s=plt.figure(figsize=(10,7))
plt.title("Customer_satisfaction_with_facilities_onboard", bbox={'facecolor':'0.7', 'pad':5})
plt.pie(data_s,labels=col)
plt.show()

# %%
dframe=pd.read_csv ('Invistico_Airline.csv')
ins1 = dframe.copy()
ins1['GenderXClassXCustomerType'] = ins1['Gender'] +'-'+ins1['Class'] +'-'+ins1['Customer Type']
insight1 = ins1.groupby(['GenderXClassXCustomerType','satisfaction']).agg({'Gender':'count'}).reset_index()
insight1.columns = ['Gender X Class X CustomerType','satisfaction','No_of_customers']
insight1
# Out:
#         Gender X Class X CustomerType  satisfaction  No_of_customers
# 0      Female-Business-Loyal Customer  dissatisfied             5843
# 1      Female-Business-Loyal Customer     satisfied            20651
# 2   Female-Business-disloyal Customer  dissatisfied             2891
# 3   Female-Business-disloyal Customer     satisfied             1878
# 4      Female-Eco Plus-Loyal Customer  dissatisfied             1434
# 5      Female-Eco Plus-Loyal Customer     satisfied             2811
# 6   Female-Eco Plus-disloyal Customer  dissatisfied              662
# 7   Female-Eco Plus-disloyal Customer     satisfied               59
# 8           Female-Eco-Loyal Customer  dissatisfied             5801
# 9           Female-Eco-Loyal Customer     satisfied            16516
# 10       Female-Eco-disloyal Customer  dissatisfied             6340
# 11       Female-Eco-disloyal Customer     satisfied             1013
# 12       Male-Business-Loyal Customer  dissatisfied             6653
# ...

# %%
gcc = insight1['Gender X Class X CustomerType']
s = insight1['satisfaction']
jcc = insight1['No_of_customers']
plt.figure(figsize=(15,15))
plt.title('Gender with their types and class', fontsize = 16);
sns.barplot(x = jcc, y = gcc, hue = s);
plt.ylabel('Customer', fontsize = 12)
plt.xlabel('satisfaction', fontsize = 12);

# %%
ins2=dframe.copy()
fig,axs = plt.subplots(2,2,figsize=(14, 14))
cols=['Gender', 'Customer Type', 'Type of Travel', 'Class']
c=0
for i in range(2):
  for j in range(2):
    sns.countplot(data=ins2,x=cols[c],hue='satisfaction',ax=axs[i][j])
    axs[i][j].set_title('Customer Satisafaction as per {}'.format(cols[c]))
    c+=1

# %%
df.head()
# Out:
#    satisfaction  Gender  Customer Type  Age  Class  Flight Distance  \
# 0             1  Female              1   65      0              265
# 1             1    Male              1   47      2             2464
# 2             1  Female              1   15      0             2138
# 3             1  Female              1   60      0              623
# 4             1  Female              1   70      0              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Inflight wifi service  ...  On-board service  Leg room service  \
# 0                      2  ...                 3                 0
# ...

# %%
import sklearn

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median())
df['Totaldelay'] = df['Totaldelay'].fillna(df['Totaldelay'].median())
df.head()

# %%
df.isna().sum()
# Out:
# satisfaction                         0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# Totaldelay                           0
# onlineservices                       0
# dtype: int64

# %%
df3 = df['satisfaction']

# %%
df4 = df.drop('satisfaction',axis=1)

# %%
df3.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: satisfaction, dtype: int64

# %%
df4.head()
# Out:
#    Gender  Customer Type  Age  Class  Flight Distance  Seat comfort  \
# 0  Female              1   65      0              265             0
# 1    Male              1   47      2             2464             0
# 2  Female              1   15      0             2138             0
# 3  Female              1   60      0              623             0
# 4  Female              1   70      0              354             0
#
#    Departure/Arrival time convenient  Food and drink  Inflight wifi service  \
# 0                                  0               0                      2
# 1                                  0               0                      0
# 2                                  0               0                      2
# 3                                  0               0                      3
# 4                                  0               0                      4
#
#    Inflight entertainment  ...  On-board service  Leg room service  \
# ...

# %%
df4.replace('Female',int(0),inplace = True)

# %%
df4.replace('Male',int(1),inplace = True)

# %%
df4.head()
# Out:
#    Gender  Customer Type  Age  Class  Flight Distance  Seat comfort  \
# 0       0              1   65      0              265             0
# 1       1              1   47      2             2464             0
# 2       0              1   15      0             2138             0
# 3       0              1   60      0              623             0
# 4       0              1   70      0              354             0
#
#    Departure/Arrival time convenient  Food and drink  Inflight wifi service  \
# 0                                  0               0                      2
# 1                                  0               0                      0
# 2                                  0               0                      2
# 3                                  0               0                      3
# 4                                  0               0                      4
#
#    Inflight entertainment  ...  On-board service  Leg room service  \
# ...

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.820860281285289
